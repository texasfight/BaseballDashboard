# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from pathlib import Path

# %%
DATA_DIR = Path(r"C:\Users\irvin\Chainopt\BaseballDashboard\baseballdatabank-2022.2").absolute()

# %%
teams = pd.read_csv(DATA_DIR / "upstream" / "Teams.csv")

# %%
teams[teams["yearID"] == 2021]
# Out:
#       yearID lgID teamID franchID divID  Rank  Ghome DivWin WCWin LgWin WSWin  \
# 2955    2021   NL    ARI      ARI     W     5   81.0      N     N     N     N
# 2956    2021   NL    ATL      ATL     E     1   80.0      Y     N     Y     Y
# 2957    2021   AL    BAL      BAL     E     5   81.0      N     N     N     N
# 2958    2021   AL    BOS      BOS     E     2   81.0      N     Y     N     N
# 2959    2021   AL    CHA      CHW     C     1   81.0      Y     N     N     N
# 2960    2021   NL    CHN      CHC     C     4   81.0      N     N     N     N
# 2961    2021   NL    CIN      CIN     C     3   81.0      N     N     N     N
# 2962    2021   AL    CLE      CLE     C     2   81.0      N     N     N     N
# 2963    2021   NL    COL      COL     W     4   81.0      N     N     N     N
# 2964    2021   AL    DET      DET     C     3   81.0      N     N     N     N
# 2965    2021   AL    HOU      HOU     W     1   81.0      Y     N     Y     N
# ...

# %%
batting = pd.read_csv(DATA_DIR / "core" / "Batting.csv")

# %%
batting[batting["yearID"] == 2021].sort_values("HR", ascending=False)
# Out:
#          playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 109960  perezsa02    2021      1    KCA   AL  161  620   88  169  24  ...
# 109401  guerrvl02    2021      1    TOR   AL  161  604  123  188  29  ...
# 109896  ohtansh01    2021      1    LAA   AL  158  537  103  138  26  ...
# 110173  semiema01    2021      1    TOR   AL  162  652  115  173  39  ...
# 110288  tatisfe02    2021      1    SDN   NL  130  478   99  135  31  ...
# ...           ...     ...    ...    ...  ...  ...  ...  ...  ...  ..  ...
# 109575  kenneia01    2021      1    TEX   AL   32    0    0    0   0  ...
# 109573  kellyme01    2021      1    ARI   NL   27   47    1    3   1  ...
# 109572  kellyjo05    2021      1    LAN   NL   48    3    0    0   0  ...
# 108929  bergetr01    2021      1    TOR   AL   10    0    0    0   0  ...
# 108789   abadfe01    2021      1    BAL   AL   16    0    0    0   0  ...
#
#           RBI    SB    CS  BB     SO   IBB   HBP   SH   SF  GIDP
# ...
